# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atar
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | richards bay
# Processing Record 4 of Set 1 | kahului
# Processing Record 5 of Set 1 | jackson
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | nicoya
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | kendal
# Processing Record 12 of Set 1 | ilulissat
# Processing Record 13 of Set 1 | beloha
# Processing Record 14 of Set 1 | brae
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | bandarbeyla
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | bambanglipuro
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | saskylakh
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | kulhudhuffushi
# Processing Record 27 of Set 1 | butembo
# Processing Record 28 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 1 | sao joao da barra
# Processing Record 34 of Set 1 | adrar
# Processing Record 35 of Set 1 | youghal
# Processing Record 36 of Set 1 | cayenne
# Processing Record 37 of Set 1 | sitka
# Processing Record 38 of Set 1 | san andres
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | sorland
# Processing Record 41 of Set 1 | khani
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | bam
# Processing Record 44 of Set 1 | tahta
# Processing Record 45 of Set 1 | vanimo
# Processing Record 46 of Set 1 | madimba
# Processing Record 47 of Set 1 | melville
# Processing Record 48 of Set 1 | nome
# Processing Record 49 of Set 1 | aswan
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | olinda
# Processing Record 3 of Set 2 | cabo san lucas
# Processing Record 4 of Set 2 | mantenopolis
# Processing Record 5 of Set 2 | kaeo
# Processing Record 6 of Set 2 | madison
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | kroderen
# City not found. Skipping...
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | bilibino
# Processing Record 11 of Set 2 | lagoa
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | upernavik
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | tupik
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | mehamn
# Processing Record 19 of Set 2 | rikitea
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | longyearbyen
# Processing Record 22 of Set 2 | tuatapere
# Processing Record 23 of Set 2 | evensk
# Processing Record 24 of Set 2 | vila velha
# Processing Record 25 of Set 2 | hue
# Processing Record 26 of Set 2 | demyansk
# Processing Record 27 of Set 2 | casper
# Processing Record 28 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 2 | iqaluit
# Processing Record 30 of Set 2 | sao felix do xingu
# Processing Record 31 of Set 2 | charlestown
# Processing Record 32 of Set 2 | mandalgovi
# Processing Record 33 of Set 2 | lugovoy
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | stillwater
# Processing Record 36 of Set 2 | provideniya
# Processing Record 37 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 2 | macklin
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | ballina
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | san cristobal
# Processing Record 43 of Set 2 | cotonou
# Processing Record 44 of Set 2 | lucea
# Processing Record 45 of Set 2 | nikolskoye
# Processing Record 46 of Set 2 | vila
# Processing Record 47 of Set 2 | lancaster
# Processing Record 48 of Set 2 | coro
# Processing Record 49 of Set 2 | alberdi
# Processing Record 50 of Set 2 | beisfjord
# Processing Record 1 of Set 3 | podosinovets
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | guerrero negro
# Processing Record 4 of Set 3 | severo-kurilsk
# Processing Record 5 of Set 3 | kemijarvi
# Processing Record 6 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 3 | souillac
# Processing Record 8 of Set 3 | khatanga
# Processing Record 9 of Set 3 | roswell
# Processing Record 10 of Set 3 | rosarito
# Processing Record 11 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 3 | puerto montt
# Processing Record 13 of Set 3 | chuy
# Processing Record 14 of Set 3 | hobart
# Processing Record 15 of Set 3 | hongjiang
# Processing Record 16 of Set 3 | touros
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | cairns
# Processing Record 19 of Set 3 | tomatlan
# Processing Record 20 of Set 3 | harare
# Processing Record 21 of Set 3 | santa maria
# Processing Record 22 of Set 3 | sint michiel
# City not found. Skipping...
# Processing Record 23 of Set 3 | camiri
# Processing Record 24 of Set 3 | la romana
# Processing Record 25 of Set 3 | saint george
# Processing Record 26 of Set 3 | caravelas
# Processing Record 27 of Set 3 | leningradskiy
# Processing Record 28 of Set 3 | sande
# Processing Record 29 of Set 3 | poum
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | la ronge
# Processing Record 32 of Set 3 | maple creek
# Processing Record 33 of Set 3 | thompson
# Processing Record 34 of Set 3 | rexburg
# Processing Record 35 of Set 3 | hay river
# Processing Record 36 of Set 3 | hervey bay
# Processing Record 37 of Set 3 | katghora
# Processing Record 38 of Set 3 | fairbanks
# Processing Record 39 of Set 3 | kismayo
# Processing Record 40 of Set 3 | talara
# Processing Record 41 of Set 3 | jardim
# Processing Record 42 of Set 3 | namatanai
# Processing Record 43 of Set 3 | lavrentiya
# Processing Record 44 of Set 3 | bubaque
# Processing Record 45 of Set 3 | codajas
# Processing Record 46 of Set 3 | constitucion
# Processing Record 47 of Set 3 | sangin
# Processing Record 48 of Set 3 | college
# Processing Record 49 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 3 | hualmay
# Processing Record 1 of Set 4 | aleksandrov gay
# Processing Record 2 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 3 of Set 4 | florianopolis
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | novikovo
# Processing Record 6 of Set 4 | shaoguan
# Processing Record 7 of Set 4 | comodoro rivadavia
# Processing Record 8 of Set 4 | bichura
# Processing Record 9 of Set 4 | plettenberg bay
# Processing Record 10 of Set 4 | qaanaaq
# Processing Record 11 of Set 4 | naantali
# Processing Record 12 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 4 | te anau
# Processing Record 14 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 4 | vardo
# Processing Record 16 of Set 4 | pevek
# Processing Record 17 of Set 4 | qandala
# Processing Record 18 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 4 | kalabo
# Processing Record 20 of Set 4 | mareeba
# Processing Record 21 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 4 | srednekolymsk
# Processing Record 23 of Set 4 | portland
# Processing Record 24 of Set 4 | goderich
# Processing Record 25 of Set 4 | yellowknife
# Processing Record 26 of Set 4 | ilo
# Processing Record 27 of Set 4 | bendigo
# Processing Record 28 of Set 4 | xuddur
# Processing Record 29 of Set 4 | ardakan
# Processing Record 30 of Set 4 | roma
# Processing Record 31 of Set 4 | port blair
# Processing Record 32 of Set 4 | kavali
# Processing Record 33 of Set 4 | hurricane
# Processing Record 34 of Set 4 | atambua
# Processing Record 35 of Set 4 | victoria
# Processing Record 36 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 4 | coffs harbour
# Processing Record 38 of Set 4 | cherskiy
# Processing Record 39 of Set 4 | olga
# Processing Record 40 of Set 4 | bozdar
# Processing Record 41 of Set 4 | aklavik
# Processing Record 42 of Set 4 | fukue
# Processing Record 43 of Set 4 | magadan
# Processing Record 44 of Set 4 | norman wells
# Processing Record 45 of Set 4 | lata
# Processing Record 46 of Set 4 | nhamunda
# Processing Record 47 of Set 4 | mbandaka
# Processing Record 48 of Set 4 | xuzhou
# Processing Record 49 of Set 4 | lompoc
# Processing Record 50 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 5 | chokurdakh
# Processing Record 2 of Set 5 | flinders
# Processing Record 3 of Set 5 | kangaatsiaq
# Processing Record 4 of Set 5 | teluknaga
# Processing Record 5 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 5 | bambous virieux
# Processing Record 7 of Set 5 | naze
# Processing Record 8 of Set 5 | ancud
# Processing Record 9 of Set 5 | wisconsin rapids
# Processing Record 10 of Set 5 | port alfred
# Processing Record 11 of Set 5 | porto santo
# Processing Record 12 of Set 5 | najran
# Processing Record 13 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 5 | luderitz
# Processing Record 15 of Set 5 | salalah
# Processing Record 16 of Set 5 | rosetta
# Processing Record 17 of Set 5 | oga
# Processing Record 18 of Set 5 | tigil
# Processing Record 19 of Set 5 | pisco
# Processing Record 20 of Set 5 | nouakchott
# Processing Record 21 of Set 5 | portel
# Processing Record 22 of Set 5 | krasnaya gora
# Processing Record 23 of Set 5 | narsaq
# Processing Record 24 of Set 5 | talnakh
# Processing Record 25 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 5 | omsukchan
# Processing Record 27 of Set 5 | heiligenhafen
# Processing Record 28 of Set 5 | esna
# Processing Record 29 of Set 5 | camopi
# Processing Record 30 of Set 5 | kupang
# Processing Record 31 of Set 5 | concordia
# Processing Record 32 of Set 5 | ostrovnoy
# Processing Record 33 of Set 5 | noumea
# Processing Record 34 of Set 5 | gondanglegi
# Processing Record 35 of Set 5 | collierville
# Processing Record 36 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 5 | esperance
# Processing Record 38 of Set 5 | hami
# Processing Record 39 of Set 5 | vaitape
# Processing Record 40 of Set 5 | kununurra
# Processing Record 41 of Set 5 | isla vista
# Processing Record 42 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 5 | isangel
# Processing Record 44 of Set 5 | opmeer
# Processing Record 45 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | los alamos
# Processing Record 48 of Set 5 | chardara
# Processing Record 49 of Set 5 | luleburgaz
# Processing Record 50 of Set 5 | sao filipe
# Processing Record 1 of Set 6 | andros
# Processing Record 2 of Set 6 | ponta do sol
# Processing Record 3 of Set 6 | novo aripuana
# Processing Record 4 of Set 6 | chernyanka
# Processing Record 5 of Set 6 | auki
# Processing Record 6 of Set 6 | kirkwall
# Processing Record 7 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 6 | ongandjera
# Processing Record 9 of Set 6 | belaya gora
# Processing Record 10 of Set 6 | rocky mountain house
# Processing Record 11 of Set 6 | tuktoyaktuk
# Processing Record 12 of Set 6 | skibbereen
# Processing Record 13 of Set 6 | nurota
# Processing Record 14 of Set 6 | antalaha
# Processing Record 15 of Set 6 | ukiah
# Processing Record 16 of Set 6 | yebaishou
# Processing Record 17 of Set 6 | saldanha
# Processing Record 18 of Set 6 | wakkanai
# Processing Record 19 of Set 6 | port macquarie
# Processing Record 20 of Set 6 | baykit
# Processing Record 21 of Set 6 | kenai
# Processing Record 22 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 6 | paldiski
# Processing Record 24 of Set 6 | hasaki
# Processing Record 25 of Set 6 | madera
# Processing Record 26 of Set 6 | fairhope
# Processing Record 27 of Set 6 | ylojarvi
# Processing Record 28 of Set 6 | pangnirtung
# Processing Record 29 of Set 6 | torbay
# Processing Record 30 of Set 6 | quatre cocos
# Processing Record 31 of Set 6 | cruzeiro do sul
# Processing Record 32 of Set 6 | xining
# Processing Record 33 of Set 6 | bowen
# Processing Record 34 of Set 6 | nanortalik
# Processing Record 35 of Set 6 | anadyr
# Processing Record 36 of Set 6 | broome
# Processing Record 37 of Set 6 | sisimiut
# Processing Record 38 of Set 6 | sheridan
# Processing Record 39 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 6 | asau
# Processing Record 41 of Set 6 | poya
# Processing Record 42 of Set 6 | nago
# Processing Record 43 of Set 6 | lorengau
# Processing Record 44 of Set 6 | trairi
# Processing Record 45 of Set 6 | mashhad
# Processing Record 46 of Set 6 | saint-philippe
# Processing Record 47 of Set 6 | monrovia
# Processing Record 48 of Set 6 | egvekinot
# Processing Record 49 of Set 6 | carnarvon
# Processing Record 50 of Set 6 | rehoboth
# Processing Record 1 of Set 7 | tevaitoa
# Processing Record 2 of Set 7 | nantucket
# Processing Record 3 of Set 7 | lebu
# Processing Record 4 of Set 7 | muros
# Processing Record 5 of Set 7 | bijar
# Processing Record 6 of Set 7 | stornoway
# Processing Record 7 of Set 7 | bilma
# Processing Record 8 of Set 7 | faanui
# Processing Record 9 of Set 7 | mangrol
# Processing Record 10 of Set 7 | usinsk
# Processing Record 11 of Set 7 | tura
# Processing Record 12 of Set 7 | otane
# Processing Record 13 of Set 7 | bolshaya sosnova
# Processing Record 14 of Set 7 | dali
# Processing Record 15 of Set 7 | mount gambier
# Processing Record 16 of Set 7 | itoman
# Processing Record 17 of Set 7 | marana
# Processing Record 18 of Set 7 | sur
# Processing Record 19 of Set 7 | prince rupert
# Processing Record 20 of Set 7 | fomboni
# Processing Record 21 of Set 7 | piacabucu
# Processing Record 22 of Set 7 | husavik
# Processing Record 23 of Set 7 | dingle
# Processing Record 24 of Set 7 | visby
# Processing Record 25 of Set 7 | pemex
# Processing Record 26 of Set 7 | amuntai
# Processing Record 27 of Set 7 | joshimath
# Processing Record 28 of Set 7 | maniitsoq
# Processing Record 29 of Set 7 | fortuna
# Processing Record 30 of Set 7 | itupiranga
# Processing Record 31 of Set 7 | goya
# Processing Record 32 of Set 7 | dunedin
# Processing Record 33 of Set 7 | paita
# Processing Record 34 of Set 7 | pacific grove
# Processing Record 35 of Set 7 | rio grande
# Processing Record 36 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 37 of Set 7 | hamilton
# Processing Record 38 of Set 7 | banda aceh
# Processing Record 39 of Set 7 | klaksvik
# Processing Record 40 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 41 of Set 7 | burnie
# Processing Record 42 of Set 7 | mporokoso
# Processing Record 43 of Set 7 | koshurnikovo
# Processing Record 44 of Set 7 | gobabis
# Processing Record 45 of Set 7 | perth
# Processing Record 46 of Set 7 | mana
# Processing Record 47 of Set 7 | neryungri
# Processing Record 48 of Set 7 | progreso
# Processing Record 49 of Set 7 | hlobyne
# Processing Record 50 of Set 7 | geraldton
# Processing Record 1 of Set 8 | maromitsa
# Processing Record 2 of Set 8 | saint-pierre
# Processing Record 3 of Set 8 | north bend
# Processing Record 4 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 8 | litovko
# Processing Record 6 of Set 8 | peachland
# Processing Record 7 of Set 8 | padang
# Processing Record 8 of Set 8 | buin
# Processing Record 9 of Set 8 | palaia fokaia
# Processing Record 10 of Set 8 | san julian
# Processing Record 11 of Set 8 | xushan
# Processing Record 12 of Set 8 | tolbazy
# Processing Record 13 of Set 8 | soverato
# Processing Record 14 of Set 8 | xinmin
# Processing Record 15 of Set 8 | tashla
# Processing Record 16 of Set 8 | illela
# Processing Record 17 of Set 8 | pak phanang
# Processing Record 18 of Set 8 | tezu
# Processing Record 19 of Set 8 | muravlenko
# Processing Record 20 of Set 8 | tepeojuma
# Processing Record 21 of Set 8 | arlit
# Processing Record 22 of Set 8 | katsuura
# Processing Record 23 of Set 8 | pemberton
# Processing Record 24 of Set 8 | lagos
# Processing Record 25 of Set 8 | ribeira grande
# Processing Record 26 of Set 8 | mwinilunga
# Processing Record 27 of Set 8 | tommot
# Processing Record 28 of Set 8 | marzuq
# Processing Record 29 of Set 8 | kitimat
# Processing Record 30 of Set 8 | verkhnetulomskiy
# Processing Record 31 of Set 8 | kosh-agach
# Processing Record 32 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 33 of Set 8 | tromso
# Processing Record 34 of Set 8 | itarema
# Processing Record 35 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 8 | chitral
# Processing Record 37 of Set 8 | skegness
# Processing Record 38 of Set 8 | nemuro
# Processing Record 39 of Set 8 | kodiak
# Processing Record 40 of Set 8 | genhe
# Processing Record 41 of Set 8 | leverkusen
# Processing Record 42 of Set 8 | hofn
# Processing Record 43 of Set 8 | menongue
# Processing Record 44 of Set 8 | payo
# Processing Record 45 of Set 8 | bagotville
# Processing Record 46 of Set 8 | ahipara
# Processing Record 47 of Set 8 | road town
# Processing Record 48 of Set 8 | morondava
# Processing Record 49 of Set 8 | mastic beach
# Processing Record 50 of Set 8 | oropesa
# Processing Record 1 of Set 9 | latung
# Processing Record 2 of Set 9 | makakilo city
# Processing Record 3 of Set 9 | sarh
# Processing Record 4 of Set 9 | chicama
# Processing Record 5 of Set 9 | khalkhal
# Processing Record 6 of Set 9 | mecca
# Processing Record 7 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 8 of Set 9 | nsanje
# Processing Record 9 of Set 9 | michurinsk
# Processing Record 10 of Set 9 | kavieng
# Processing Record 11 of Set 9 | kuryk
# Processing Record 12 of Set 9 | abu samrah
# Processing Record 13 of Set 9 | monticello
# Processing Record 14 of Set 9 | san quintin
# Processing Record 15 of Set 9 | cidreira
# Processing Record 16 of Set 9 | sechura
# Processing Record 17 of Set 9 | alugan
# Processing Record 18 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 9 | erzin
# Processing Record 20 of Set 9 | zepce
# Processing Record 21 of Set 9 | charters towers
# Processing Record 22 of Set 9 | igarka
# Processing Record 23 of Set 9 | kattivakkam
# Processing Record 24 of Set 9 | redhakhol
# City not found. Skipping...
# Processing Record 25 of Set 9 | kibala
# Processing Record 26 of Set 9 | mayo
# Processing Record 27 of Set 9 | gizo
# Processing Record 28 of Set 9 | athens
# Processing Record 29 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 9 | sidney
# Processing Record 31 of Set 9 | yumen
# Processing Record 32 of Set 9 | salamiyah
# Processing Record 33 of Set 9 | ishigaki
# Processing Record 34 of Set 9 | acajutla
# Processing Record 35 of Set 9 | yambio
# Processing Record 36 of Set 9 | monte cristi
# City not found. Skipping...
# Processing Record 37 of Set 9 | alofi
# Processing Record 38 of Set 9 | hambantota
# Processing Record 39 of Set 9 | west wendover
# Processing Record 40 of Set 9 | airai
# Processing Record 41 of Set 9 | orsha
# Processing Record 42 of Set 9 | tessalit
# Processing Record 43 of Set 9 | tsabong
# Processing Record 44 of Set 9 | santiago del estero
# Processing Record 45 of Set 9 | codrington
# Processing Record 46 of Set 9 | zeya
# Processing Record 47 of Set 9 | notodden
# Processing Record 48 of Set 9 | inverell
# Processing Record 49 of Set 9 | grand gaube
# Processing Record 50 of Set 9 | verkhnyaya inta
# Processing Record 1 of Set 10 | kalmunai
# Processing Record 2 of Set 10 | galle
# Processing Record 3 of Set 10 | san policarpo
# Processing Record 4 of Set 10 | mahebourg
# Processing Record 5 of Set 10 | konstantinovka
# Processing Record 6 of Set 10 | daru
# Processing Record 7 of Set 10 | aykhal
# Processing Record 8 of Set 10 | sao joao do piaui
# Processing Record 9 of Set 10 | gushikawa
# Processing Record 10 of Set 10 | chabua
# Processing Record 11 of Set 10 | skreia
# Processing Record 12 of Set 10 | kovdor
# Processing Record 13 of Set 10 | kathmandu
# Processing Record 14 of Set 10 | haines junction
# Processing Record 15 of Set 10 | mendeleyevsk
# Processing Record 16 of Set 10 | samarai
# Processing Record 17 of Set 10 | dauphin
# Processing Record 18 of Set 10 | kuvshinovo
# Processing Record 19 of Set 10 | maldonado
# Processing Record 20 of Set 10 | rawson
# Processing Record 21 of Set 10 | surt
# Processing Record 22 of Set 10 | bairiki
# Processing Record 23 of Set 10 | manaring
# Processing Record 24 of Set 10 | puerto del rosario
# Processing Record 25 of Set 10 | edd
# Processing Record 26 of Set 10 | inirida
# Processing Record 27 of Set 10 | north platte
# Processing Record 28 of Set 10 | lubumbashi
# Processing Record 29 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 10 | yar-sale
# Processing Record 31 of Set 10 | dakoro
# Processing Record 32 of Set 10 | cortez
# Processing Record 33 of Set 10 | petit goave
# Processing Record 34 of Set 10 | bisalpur
# Processing Record 35 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 10 | ketchikan
# Processing Record 37 of Set 10 | mariental
# Processing Record 38 of Set 10 | port augusta
# Processing Record 39 of Set 10 | show low
# Processing Record 40 of Set 10 | taoudenni
# Processing Record 41 of Set 10 | berwick
# Processing Record 42 of Set 10 | palmer
# Processing Record 43 of Set 10 | clinton
# Processing Record 44 of Set 10 | tiksi
# Processing Record 45 of Set 10 | viedma
# Processing Record 46 of Set 10 | enid
# Processing Record 47 of Set 10 | cravo norte
# Processing Record 48 of Set 10 | peterhead
# Processing Record 49 of Set 10 | bulgan
# Processing Record 50 of Set 10 | belmonte
# Processing Record 1 of Set 11 | tilichiki
# Processing Record 2 of Set 11 | yulara
# Processing Record 3 of Set 11 | mouila
# Processing Record 4 of Set 11 | sinnamary
# Processing Record 5 of Set 11 | umm kaddadah
# Processing Record 6 of Set 11 | veraval
# Processing Record 7 of Set 11 | palamos
# Processing Record 8 of Set 11 | shimoda
# Processing Record 9 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 11 | yellandu
# Processing Record 11 of Set 11 | zyryanka
# Processing Record 12 of Set 11 | redmond
# Processing Record 13 of Set 11 | vao
# Processing Record 14 of Set 11 | minot
# Processing Record 15 of Set 11 | coihaique
# Processing Record 16 of Set 11 | havelock
# Processing Record 17 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 11 | suraabad
# Processing Record 19 of Set 11 | grand island
# Processing Record 20 of Set 11 | jambi
# Processing Record 21 of Set 11 | rio gallegos
# Processing Record 22 of Set 11 | soubre
# Processing Record 23 of Set 11 | kavarna
# Processing Record 24 of Set 11 | dhidhdhoo
# Processing Record 25 of Set 11 | severobaykalsk
# Processing Record 26 of Set 11 | deputatskiy
# Processing Record 27 of Set 11 | bentong
# Processing Record 28 of Set 11 | flin flon
# Processing Record 29 of Set 11 | krasnovishersk
# Processing Record 30 of Set 11 | casambalangan
# Processing Record 31 of Set 11 | wonthaggi
# Processing Record 32 of Set 11 | bagdarin
# Processing Record 33 of Set 11 | lahan
# Processing Record 34 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 11 | pitimbu
# Processing Record 36 of Set 11 | chake chake
# Processing Record 37 of Set 11 | cururupu
# Processing Record 38 of Set 11 | karpathos
# Processing Record 39 of Set 11 | ambalavao
# Processing Record 40 of Set 11 | fengxian
# Processing Record 41 of Set 11 | flers
# Processing Record 42 of Set 11 | cockburn town
# Processing Record 43 of Set 11 | fenton
# Processing Record 44 of Set 11 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 45 of Set 11 | ambon
# Processing Record 46 of Set 11 | ayorou
# Processing Record 47 of Set 11 | alyangula
# Processing Record 48 of Set 11 | marsh harbour
# Processing Record 49 of Set 11 | kigoma
# Processing Record 50 of Set 11 | tadine
# Processing Record 1 of Set 12 | porto novo
# Processing Record 2 of Set 12 | utevka
# Processing Record 3 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 4 of Set 12 | honningsvag
# Processing Record 5 of Set 12 | tutoia
# Processing Record 6 of Set 12 | abancay
# Processing Record 7 of Set 12 | genova
# Processing Record 8 of Set 12 | nizhniy chir
# Processing Record 9 of Set 12 | pontes e lacerda
# Processing Record 10 of Set 12 | price
# Processing Record 11 of Set 12 | borogontsy
# Processing Record 12 of Set 12 | hanmer springs
# Processing Record 13 of Set 12 | dinguiraye
# Processing Record 14 of Set 12 | khasan
# Processing Record 15 of Set 12 | taga
# Processing Record 16 of Set 12 | chipinge
# Processing Record 17 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 18 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 19 of Set 12 | alghero
# Processing Record 20 of Set 12 | kota kinabalu
# Processing Record 21 of Set 12 | warah
# Processing Record 22 of Set 12 | tongliao
# Processing Record 23 of Set 12 | coahuayana
# Processing Record 24 of Set 12 | taltal
# Processing Record 25 of Set 12 | murdochville
# Processing Record 26 of Set 12 | solnechnyy
# Processing Record 27 of Set 12 | tamale
# Processing Record 28 of Set 12 | pizarro
# Processing Record 29 of Set 12 | barra do garcas
# Processing Record 30 of Set 12 | mondovi
# Processing Record 31 of Set 12 | tsiroanomandidy
# Processing Record 32 of Set 12 | vega de alatorre
# Processing Record 33 of Set 12 | saint-jean-port-joli
# Processing Record 34 of Set 12 | inhambane
# Processing Record 35 of Set 12 | abha
# Processing Record 36 of Set 12 | banjar
# Processing Record 37 of Set 12 | grindavik
# Processing Record 38 of Set 12 | tecoanapa
# Processing Record 39 of Set 12 | half moon bay
# Processing Record 40 of Set 12 | kozhevnikovo
# Processing Record 41 of Set 12 | nelson bay
# Processing Record 42 of Set 12 | vung tau
# Processing Record 43 of Set 12 | ewo
# Processing Record 44 of Set 12 | port hardy
# Processing Record 45 of Set 12 | kaseda
# Processing Record 46 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 47 of Set 12 | damghan
# Processing Record 48 of Set 12 | paramonga
# Processing Record 49 of Set 12 | iisalmi
# Processing Record 50 of Set 12 | de aar
# Processing Record 1 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 13 | adilpur
# Processing Record 3 of Set 13 | mitsamiouli
# Processing Record 4 of Set 13 | syriam
# Processing Record 5 of Set 13 | rapid valley
# Processing Record 6 of Set 13 | harnosand
# Processing Record 7 of Set 13 | ruian
# City not found. Skipping...
# Processing Record 8 of Set 13 | agadez
# Processing Record 9 of Set 13 | abonnema
# Processing Record 10 of Set 13 | lokoja
# Processing Record 11 of Set 13 | taman
# Processing Record 12 of Set 13 | rincon
# Processing Record 13 of Set 13 | sosnovo-ozerskoye
# Processing Record 14 of Set 13 | saint-georges
# Processing Record 15 of Set 13 | gornopravdinsk
# Processing Record 16 of Set 13 | sarlat-la-caneda
# Processing Record 17 of Set 13 | tabou
# Processing Record 18 of Set 13 | boyolangu
# Processing Record 19 of Set 13 | saint-francois
# Processing Record 20 of Set 13 | elko
# Processing Record 21 of Set 13 | darhan
# Processing Record 22 of Set 13 | carballo
# Processing Record 23 of Set 13 | khandbari
# Processing Record 24 of Set 13 | muzhi
# Processing Record 25 of Set 13 | farafangana
# Processing Record 26 of Set 13 | simao
# Processing Record 27 of Set 13 | monroe
# Processing Record 28 of Set 13 | san jose
# Processing Record 29 of Set 13 | ambanja
# Processing Record 30 of Set 13 | kaohsiung
# Processing Record 31 of Set 13 | miandrivazo
# Processing Record 32 of Set 13 | arona
# Processing Record 33 of Set 13 | san patricio
# Processing Record 34 of Set 13 | bereda
# Processing Record 35 of Set 13 | konya
# Processing Record 36 of Set 13 | savonlinna
# Processing Record 37 of Set 13 | wajima
# Processing Record 38 of Set 13 | zhigansk
# Processing Record 39 of Set 13 | havoysund
# Processing Record 40 of Set 13 | dubbo
# Processing Record 41 of Set 13 | robertsport
# Processing Record 42 of Set 13 | vestmannaeyjar
# Processing Record 43 of Set 13 | vakhrushi
# Processing Record 44 of Set 13 | kirkuk
# Processing Record 45 of Set 13 | matsanga
# City not found. Skipping...
# Processing Record 46 of Set 13 | sergeyevka
# Processing Record 47 of Set 13 | divnogorsk
# Processing Record 48 of Set 13 | januaria
# Processing Record 49 of Set 13 | sabang
# Processing Record 50 of Set 13 | hienghene
# Processing Record 1 of Set 14 | miles city
# Processing Record 2 of Set 14 | vidim
# Processing Record 3 of Set 14 | gat
# Processing Record 4 of Set 14 | wellington
# Processing Record 5 of Set 14 | kholmy
# Processing Record 6 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 7 of Set 14 | mazagao
# Processing Record 8 of Set 14 | henties bay
# Processing Record 9 of Set 14 | beringovskiy
# Processing Record 10 of Set 14 | varzelandia
# Processing Record 11 of Set 14 | byron bay
# Processing Record 12 of Set 14 | laguna
# Processing Record 13 of Set 14 | lulea
# Processing Record 14 of Set 14 | encheng
# Processing Record 15 of Set 14 | pipri
# Processing Record 16 of Set 14 | mozelos
# Processing Record 17 of Set 14 | lensk
# Processing Record 18 of Set 14 | olafsvik
# Processing Record 19 of Set 14 | samana
# Processing Record 20 of Set 14 | lae
# Processing Record 21 of Set 14 | dapdap
# Processing Record 22 of Set 14 | le port
# Processing Record 23 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 14 | treinta y tres
# Processing Record 25 of Set 14 | leh
# Processing Record 26 of Set 14 | namibe
# Processing Record 27 of Set 14 | zaria
# Processing Record 28 of Set 14 | rosario oeste
# Processing Record 29 of Set 14 | mukhen
# Processing Record 30 of Set 14 | bardiyah
# Processing Record 31 of Set 14 | marystown
# Processing Record 32 of Set 14 | tawnat
# City not found. Skipping...
# Processing Record 33 of Set 14 | yatou
# Processing Record 34 of Set 14 | tabulbah
# City not found. Skipping...
# Processing Record 35 of Set 14 | kysyl-syr
# Processing Record 36 of Set 14 | fort frances
# Processing Record 37 of Set 14 | sorong
# Processing Record 38 of Set 14 | artyom
# Processing Record 39 of Set 14 | razdolinsk
# Processing Record 40 of Set 14 | kiunga
# Processing Record 41 of Set 14 | llandrindod wells
# Processing Record 42 of Set 14 | keningau
# Processing Record 43 of Set 14 | muli
# Processing Record 44 of Set 14 | bitung
# Processing Record 45 of Set 14 | sarrebourg
# Processing Record 46 of Set 14 | ca mau
# Processing Record 47 of Set 14 | nosy varika
# Processing Record 48 of Set 14 | waingapu
# Processing Record 49 of Set 14 | shache
# Processing Record 50 of Set 14 | biltine
# Processing Record 1 of Set 15 | wiang sa
# Processing Record 2 of Set 15 | champerico
# Processing Record 3 of Set 15 | carbonear
# Processing Record 4 of Set 15 | kourou
# Processing Record 5 of Set 15 | viransehir
# Processing Record 6 of Set 15 | aberdeen
# Processing Record 7 of Set 15 | yerbogachen
# Processing Record 8 of Set 15 | tpig
# Processing Record 9 of Set 15 | foix
# Processing Record 10 of Set 15 | bonavista
# Processing Record 11 of Set 15 | newport
# Processing Record 12 of Set 15 | goedereede
# Processing Record 13 of Set 15 | shubarshi
# Processing Record 14 of Set 15 | pottsville
# Processing Record 15 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 16 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 15 | catamarca
# Processing Record 19 of Set 15 | gari
# Processing Record 20 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 21 of Set 15 | achacachi
# Processing Record 22 of Set 15 | port-cartier
# Processing Record 23 of Set 15 | teya
# Processing Record 24 of Set 15 | pekan
# Processing Record 25 of Set 15 | grahamstown
# Processing Record 26 of Set 15 | faya
# Processing Record 27 of Set 15 | kalmar
# Processing Record 28 of Set 15 | benguela
# Processing Record 29 of Set 15 | susaki
# Processing Record 30 of Set 15 | thinadhoo
# Processing Record 31 of Set 15 | shumskiy
# Processing Record 32 of Set 15 | dzilam gonzalez
# Processing Record 33 of Set 15 | mount isa
# Processing Record 34 of Set 15 | gurmatkal
# Processing Record 35 of Set 15 | shu
# Processing Record 36 of Set 15 | baykalsk
# Processing Record 37 of Set 15 | gimli
# Processing Record 38 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 39 of Set 15 | pyinmana
# Processing Record 40 of Set 15 | manokwari
# Processing Record 41 of Set 15 | lasa
# Processing Record 42 of Set 15 | kuala terengganu
# Processing Record 43 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 44 of Set 15 | puerto escondido
# Processing Record 45 of Set 15 | los llanos de aridane
# Processing Record 46 of Set 15 | manta
# Processing Record 47 of Set 15 | beyneu
# Processing Record 48 of Set 15 | maradi
# Processing Record 49 of Set 15 | watertown
# Processing Record 50 of Set 15 | osorno
# Processing Record 1 of Set 16 | kashi
# Processing Record 2 of Set 16 | thunder bay
# Processing Record 3 of Set 16 | durres
# Processing Record 4 of Set 16 | markova
# Processing Record 5 of Set 16 | nezhinka
# Processing Record 6 of Set 16 | palau
# Processing Record 7 of Set 16 | manali
# Processing Record 8 of Set 16 | dobson
# Processing Record 9 of Set 16 | batagay-alyta
# Processing Record 10 of Set 16 | bukama
# Processing Record 11 of Set 16 | antofagasta
# Processing Record 12 of Set 16 | bulungu
# Processing Record 13 of Set 16 | lodja
# Processing Record 14 of Set 16 | batemans bay
# Processing Record 15 of Set 16 | hirara
# Processing Record 16 of Set 16 | pampas
# Processing Record 17 of Set 16 | shediac
# Processing Record 18 of Set 16 | mouzakion
# City not found. Skipping...
# Processing Record 19 of Set 16 | mogadishu
# Processing Record 20 of Set 16 | loei
# Processing Record 21 of Set 16 | melnik
# Processing Record 22 of Set 16 | tchibanga
# Processing Record 23 of Set 16 | lishui
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Atar      MR  20.5169  -13.0499     75.11        15         100
# 1  Arraial Do Cabo      BR -22.9661  -42.0278     89.60        51           0
# 2     Richards Bay      ZA -28.7830   32.0377     74.23        80          66
# 3          Kahului      US  20.8947 -156.4700     71.60        83          40
# 4          Jackson      US  42.4165 -122.8345     41.00        93          90
# 5      New Norfolk      AU -42.7826  147.0587     60.01        76          98
# 6          Ushuaia      AR -54.8000  -68.3000     51.80        62          90
# 7           Nicoya      CR  10.1483  -85.4520     89.60        45           0
# 8         Hermanus      ZA -34.4187   19.2345     73.00        66           9
# 9           Kendal      GB  54.3268   -2.7476     43.00        94         100
#
#    Wind Speed Current Description
# 0       14.74     overcast clouds
# 1       19.57           clear sky
# 2        6.29          light rain
# 3        6.91    scattered clouds
# 4        8.05                 fog
# 5        5.01     overcast clouds
# 6        6.24             drizzle
# 7       10.36           clear sky
# 8        4.00           clear sky
# 9        1.99     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
